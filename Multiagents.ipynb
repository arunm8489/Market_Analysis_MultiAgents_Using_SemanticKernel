# %% [markdown]
# ### Importing Libraries

# %%
import asyncio,yaml,json
from typing import TYPE_CHECKING, Annotated
from utils import *
from semantic_kernel import Kernel
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai import FunctionChoiceBehavior
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
from semantic_kernel.contents import ChatHistory
from semantic_kernel.contents.function_call_content import FunctionCallContent
from semantic_kernel.contents.function_result_content import FunctionResultContent
from semantic_kernel.functions import KernelArguments, kernel_function
from semantic_kernel.prompt_template import InputVariable, PromptTemplateConfig
import logging,re
from semantic_kernel.functions import KernelFunctionFromPrompt
from openai import AzureOpenAI
from utils import *
from Plugins.searchplugin import SearchPlugin
from Plugins.emailplugin import EmailPlugin
# logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %% [markdown]
# # Search Agent

# %% [markdown]
# ### Initialize kernel

# %%
##initializing kernel
search_agent_kernel = Kernel()

## adding model as service to kernel
sk_client = AzureChatCompletion(async_client=get_openai_client(), service_id="4o-agent", deployment_name="gpt-4o")
search_agent_kernel.add_service(service=sk_client)

# %% [markdown]
# **Adding plugins**
#
# SearchAgent requires 2 plugins
#
# 1. Search Plugin: to search stock related news
# 2. Time Plugin: to calculate date and time

# %%
from Plugins.searchplugin import SearchPlugin
from semantic_kernel.core_plugins.time_plugin import TimePlugin


search_plugin = SearchPlugin()
time_plugin = TimePlugin()

## adding plugins to kernel
search_agent_kernel.add_plugin(plugin=search_plugin,plugin_name="SearchPlugin")
search_agent_kernel.add_plugin(plugin=time_plugin,plugin_name="TimePlugin")
# Out:
# KernelPlugin(name='TimePlugin', description=None, functions={'date': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='date', plugin_name='TimePlugin', description='Get the current date.', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdda0>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fde10>, method=<bound method TimePlugin.date of TimePlugin()>, stream_method=None), 'date_matching_last_day_name': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='date_matching_last_day_name', plugin_name='TimePlugin', description='Get the date of the last day matching the supplied week day name in English.', parameters=[KernelParameterMetadata(name='day_name', description=None, default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fde80>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdef0>, method=<bound method TimePlugin.date_matching_last_day_name of TimePlugin()>, stream_method=None), 'day': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='day', plugin_name='TimePlugin', description='Get the current day', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdf60>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdfd0>, method=<bound method TimePlugin.day of TimePlugin()>, stream_method=None), 'dayOfWeek': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='dayOfWeek', plugin_name='TimePlugin', description='Get the current day of the week', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fe040>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fe0b0>, method=<bound method TimePlugin.day_of_week of TimePlugin()>, stream_method=None), 'days_ago': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='days_ago', plugin_name='TimePlugin', description='Get the date of offset from today by a provided number of days', parameters=[KernelParameterMetadata(name='days', description=None, default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'stri ...

# %% [markdown]
# **Lets print all plugins**

# %%
for plugin_name, plugin in search_agent_kernel.plugins.items():
    for function_name, function in plugin.functions.items():
        print(f"Plugin: {plugin_name}, Function: {function_name}")
# Out:
# Plugin: SearchPlugin, Function: SearchCode
# Plugin: SearchPlugin, Function: SearchNews
# Plugin: TimePlugin, Function: date
# Plugin: TimePlugin, Function: date_matching_last_day_name
# Plugin: TimePlugin, Function: day
# Plugin: TimePlugin, Function: dayOfWeek
# Plugin: TimePlugin, Function: days_ago
# Plugin: TimePlugin, Function: hour
# Plugin: TimePlugin, Function: hourNumber
# Plugin: TimePlugin, Function: iso_date
# Plugin: TimePlugin, Function: minute
# Plugin: TimePlugin, Function: month
# Plugin: TimePlugin, Function: month_number
# Plugin: TimePlugin, Function: now
# Plugin: TimePlugin, Function: second
# Plugin: TimePlugin, Function: time
# Plugin: TimePlugin, Function: timeZoneName
# Plugin: TimePlugin, Function: timeZoneOffset
# Plugin: TimePlugin, Function: today
# Plugin: TimePlugin, Function: utcNow
# Plugin: TimePlugin, Function: year

# %% [markdown]
# **Get Execution settings**

# %%
## Lets get execution settings for agent
## Add execution settings of the kernel 
search_agent_execution_settings = search_agent_kernel.get_prompt_execution_settings_from_service_id(service_id="4o-agent")
# Configure the function choice behavior to auto invoke kernel functions
search_agent_execution_settings.function_choice_behavior = FunctionChoiceBehavior.Auto()
search_agent_execution_settings.parallel_tool_calls = False

# %%
# define agent
AGENT_NAME = "SearchAgent"
AGENT_INSTRUCTIONS = """

Role:
You are a financial department agent specializing in stock price analysis and related tasks.

Plugins:

SearchPlugin:

SearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.
SearchNews: Fetches financial news using a company code and date range (from_date, to_date).

TimePlugin: Manages time-related operations, including retrieving the current date.

Instructions:

Time Management:

Use TimePlugin for the current date in YYYY-MM-DD format.
Last Week: Set from_date to Monday and to_date to Friday of the previous week.
Last Month: Set from_date to the 1st and to_date to the last day of the previous month.
No Time Frame Mentioned: Use today’s date as from_date.


Company code: 
Search Code will returns a company code if the user mentions a company in the query.
This company code gets passed to SearchNews


Accuracy:
Never assume or fabricate information.
Always include the time frame in the final output.
"""



#Create the agent

search_agent = ChatCompletionAgent(
    service_id="4o-agent",
    kernel=search_agent_kernel,
    name=AGENT_NAME,
    instructions=AGENT_INSTRUCTIONS,
    arguments=KernelArguments(settings=search_agent_execution_settings))

##"excluded_plugins": ["PluginName"]}

## assigning a chat history object
chat_history = ChatHistory()

## function to chat
async def chat(user_message,agent):
    chat_history.add_user_message(user_message)
    async for response in agent.invoke(history=chat_history,verbose=True):
            print(f"{response.content}")
    chat_history.add_assistant_message(str(response))

# %%
search_agent.kernel.plugins
# Out:
# {'SearchPlugin': KernelPlugin(name='SearchPlugin', description=None, functions={'SearchCode': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='SearchCode', plugin_name='SearchPlugin', description='Extrats company name from user query and returns corresponding code', parameters=[KernelParameterMetadata(name='company_name', description='name of the company', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'name of the company'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=True, return_parameter=KernelParameterMetadata(name='return', description='code of company in stockmarket', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'code of company in stockmarket'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdc50>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdbe0>, method=<bound method SearchPlugin.search_code of <Plugins.searchplugin.SearchPlugin object at 0x11d7eead0>>, stream_method=None), 'SearchNews': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='SearchNews', plugin_name='SearchPlugin', description='fetch stock market related news for a particular timeframe.', parameters=[KernelParameterMetadata(name='from_date', description='starting date for which news is to be fetched.Expects in YYYY-MM-DD format.eg:2024-05-01', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'starting date for which news is to be fetched.Expects in YYYY-MM-DD format.eg:2024-05-01'}, include_in_function_choices=True), KernelParameterMetadata(name='company_code', description=None, default_value=None, type_='str', is_required=False, type_object=typing.Annotated[str, 'code of the company obtained from SearchCode function'], schema_data={'type': 'object'}, include_in_function_choices=True), KernelParameterMetadata(name='to_date', description=None, default_value=None, type_='str', is_required=False, type_object=typing.Annotated[str, 'end date for for which news is fetched.Expects in YYYY-MM-DD format.eg:2024-05-08'], schema_data={'type': 'object'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=True, return_parameter=KernelParameterMetadata(name='return', description='list of dict containing title and content of news', default_value=None, type_='list[dict]', is_required=True, type_object=<class 'list'>, schema_data={'type': 'array', 'description': 'list of dict containing title and content of news'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdcc0>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdd30>, method=<bound method SearchPlugin.search_news of <Plugins.searchplugin.SearchPlugin object at 0x11d7eead0>>, stream_method=None)}),
#  'TimePlugin': KernelPlugin(name='TimePlugin', description=None, functions={'date': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='date', plugin_name='TimePlugin', description='Get the current date.', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdda0>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fde10>, method=<bound method TimePlugin.date of TimePlugin()>, stream_method=None), 'date_matching_last_day_name': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='date_matching_last_day_name', plugin_name='TimePlugin', description='Get the date of the last day matching the supplied week day name in English.', parameters=[KernelParameterMetadata(name='day_name', description=None, default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fde80>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdef0>, method=<bound method TimePlugin.date_matching_last_day_name of TimePlugin()>, stream_method=None), 'day': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='day', plugin_name='TimePlugin', description='Get the current day', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdf60>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fdfd0>, method=<bound method TimePlugin.day of TimePlugin()>, stream_method=None), 'dayOfWeek': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='dayOfWeek', plugin_name='TimePlugin', description='Get the current day of the week', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fe040>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d8fe0b0>, method=<bound method TimePlugin.day_of_week of TimePlugin()>, stream_method=None), 'days_ago': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='days_ago', plugin_name='TimePlugin', description='Get the date of offset from today by a provided number of days', parameters=[KernelParameterMetadata(name='days', description=None, default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data ...

# %%
user_query = "what happend to google stocks last week"


response = await chat(user_query,agent=search_agent)
# Out:
# DEBUG:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoking AzureChatCompletion.
# DEBUG:msal.authority:Initializing with Entra authority: https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.13.0 (macOS-10.16-x86_64-i386-64bit-Mach-O)'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): login.microsoftonline.com:443
# DEBUG:urllib3.connectionpool:https://login.microsoftonline.com:443 "GET /0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration HTTP/11" 200 1753
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'max-age=86400, private'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Access-Control-Allow-Methods': 'REDACTED'
#     'P3P': 'REDACTED'
#     'x-ms-request-id': '5dbe9503-6a9c-46be-a682-c36c9ed83800'
#     'x-ms-ests-server': 'REDACTED'
#     'x-ms-srs': 'REDACTED'
#     'Content-Security-Policy-Report-Only': 'REDACTED'
#     'X-XSS-Protection': 'REDACTED'
#     'Set-Cookie': 'REDACTED'
#     'Date': 'Sat, 22 Feb 2025 18:38:04 GMT'
#     'Content-Length': '1753'
# DEBUG:msal.authority:openid_config("https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration") = {'token_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token', 'token_endpoint_auth_methods_supported': ['client_secret_post', 'private_key_jwt', 'client_secret_basic'], 'jwks_uri': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/discovery/v2.0/keys', 'response_modes_supported': ['query', 'fragment', 'form_post'], 'subject_types_supported': ['pairwise'], 'id_token_signing_alg_values_supported': ['RS256'], 'response_types_supported': ['code', 'id_token', 'code id_token', 'id_token token'], 'scopes_supported': ['openid', 'profile', 'email', 'offline_access'], 'issuer': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0', 'request_uri_parameter_supported': False, 'userinfo_endpoint': 'https://graph.microsoft.com/oidc/userinfo', 'authorization_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/authorize', 'device_authorization_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/devicecode', 'http_logout_supported': True, 'frontchannel_logout_supported': True, 'end_session_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/logout', 'claims_supported': ['sub', 'iss', 'cloud_instance_name', 'cloud_instance_host_name', 'cloud_graph_host_name', 'msgraph_host', 'aud', 'exp', 'iat', 'auth_time', 'acr', 'nonce', 'preferred_username', 'name', 'tid', 'ver', 'at_hash', 'c_hash', 'email'], 'kerberos_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/kerberos', 'tenant_region_scope': 'NA', 'cloud_instance_name': 'microsoftonline.com', 'cloud_graph_host_name': 'graph.windows.net', 'msgraph_host': 'graph.microsoft.com', 'rbac_url': 'https://pas.windows.net'}
# DEBUG:msal.application:Broker enabled? None
# DEBUG:msal.telemetry:Generate or reuse correlation_id: 16966a55-b717-4b97-92e0-751e464d8e9f
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token'
# Request method: 'POST'
# Request headers:
#     'Accept': 'application/json'
#     'x-client-sku': 'REDACTED'
#     'x-client-ver': 'REDACTED'
#     'x-client-os': 'REDACTED'
#     'x-ms-lib-capability': 'REDACTED'
#     'client-request-id': 'REDACTED'
#     'x-client-current-telemetry': 'REDACTED'
#     'x-client-last-telemetry': 'REDACTED'
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.13.0 (macOS-10.16-x86_64-i386-64bit-Mach-O)'
# A body is sent with the request
# DEBUG:urllib3.connectionpool:https://login.microsoftonline.com:443 "POST /0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token HTTP/11" 200 1376
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-store, no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'P3P': 'REDACTED'
#     'client-request-id': 'REDACTED'
#     'x-ms-request-id': '9f03f396-9367-4ac9-bd3c-b4d6ea5c0200'
#     'x-ms-ests-server': 'REDACTED'
#     'x-ms-clitelem': 'REDACTED'
#     'x-ms-srs': 'REDACTED'
#     'Content-Security-Policy-Report-Only': 'REDACTED'
#     'X-XSS-Protection': 'REDACTED'
#     'Set-Cookie': 'REDACTED'
#     'Date': 'Sat, 22 Feb 2025 18:38:04 GMT'
#     'Content-Length': '1376'
# DEBUG:msal.token_cache:event={
#     "client_id": "3d3431ad-2789-422d-ba98-0051ce1cf109",
#     "data": {
#         "claims": null,
#         "scope": [
#             "https://cognitiveservices.azure.com/.default"
#         ]
#     },
#     "environment": "login.microsoftonline.com",
#     "grant_type": "client_credentials",
#     "params": null,
#     "response": {
#         "access_token": "********",
#         "expires_in": 3599,
#         "ext_expires_in": 3599,
#         "token_type": "Bearer"
#     },
#     "scope": [
#         "https://cognitiveservices.azure.com/.default"
#     ],
#     "token_endpoint": "https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token"
# }
# INFO:azure.identity._internal.get_token_mixin:ClientSecretCredential.get_token_info succeeded
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}], 'model': 'gpt-4o', 'parallel_tool_calls': False, 'stream': False, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'description': 'Extrats company name from user query and returns corresponding code', 'parameters': {'type': 'object', 'properties': {'company_name': {'type': 'string', 'description': 'name of the company'}}, 'required': ['company_name']}}}, {'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'description': 'fetch stock market related news for a particular timeframe.', 'parameters': {'type': 'object', 'properties': {'from_date': {'type': 'string', 'description': 'starting date for which news is to be fetched.Expects in YYYY-MM-DD format.eg:2024-05-01'}, 'company_code': {'type': 'object'}, 'to_date': {'type': 'object'}}, 'required': ['from_date']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date', 'description': 'Get the current date.', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'description': 'Get the date of the last day matching the supplied week day name in English.', 'parameters': {'type': 'object', 'properties': {'day_name': {'type': 'string'}}, 'required': ['day_name']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-day', 'description': 'Get the current day', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-dayOfWeek', 'description': 'Get the current day of the week', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-days_ago', 'description': 'Get the date of offset from today by a provided number of days', 'parameters': {'type': 'object', 'properties': {'days': {'type': 'string'}}, 'required': ['days']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-hour', 'description': 'Get the current hour', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-hourNumber', 'description': 'Get the current hour number', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-iso_date', 'description': 'Get the current date in iso format.', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-minute', 'description': 'Get the current minute', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-month', 'd ...
# DEBUG:httpcore.connection:connect_tcp.started host='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d921590>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11d8c4c20> server_hostname='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d9216a0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:05 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1051'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'bb408014-d50d-421d-8427-9fc5dc45d8eb'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'd9ec6462-1e74-4334-b08d-ba48b97522c3'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206109'), (b'x-ratelimit-remaining-tokens', b'20610104'), (b'azureml-model-session', b'd345-20250220072505'), (b'x-envoy-upstream-service-time', b'341'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=18, prompt_tokens=675, total_tokens=693, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling SearchPlugin-SearchCode function with args: {"company_name":"Google"}
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchCode invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'company_name': 'Google'}
# INFO:root:COMPANY NAME: Google and COMPANY CODE: GOOG
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchCode succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: company_code='GOOG'
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.001669s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}]}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}], 'model': 'gpt-4o', 'parallel_tool_calls': False, 'stream': False, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'description': 'Extrats company name from user query and returns corresponding code', 'parameters': {'type': 'object', 'properties': {'company_name': {'type': 'string', 'description': 'name of the company'}}, 'required': ['company_name']}}}, {'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'description': 'fetch stock market related news for a particular timeframe.', 'parameters': {'type': 'object', 'properties': {'from_date': {'type': 'string', 'description': 'starting date for which news is to be fetched.Expects in YYYY-MM-DD format.eg:2024-05-01'}, 'company_code': {'type': 'object'}, 'to_date': {'type': 'object'}}, 'required': ['from_date']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date', 'description': 'Get the current date.', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'description': 'Get the date of the last day matching the supplied week day name in English.', 'parameters': {'type': 'object', 'properties': {'day_name': {'type': 'string'}}, 'required': ['day_name']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-day', 'description': 'Get the current day', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-dayOfWeek', 'description': 'Get the current day of the week', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-days_ago', 'description': 'Get the date of offset from today by a provided number of days', 'parameters': {'type': 'object', 'properties': {'days': {'type': 'string'}}, 'required': ['days']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-hour', 'description': 'Get the current hour', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-hourNumber', 'description': 'Get the current hour number', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-iso_date', 'description': 'Get the current date in iso format.', 'parameters': {' ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:06 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1062'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'b19d6a0b-09a3-49cc-b8be-ef763251d2e9'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'f577ef39-84f0-4c21-8d84-a4a1283f03c4'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206108'), (b'x-ratelimit-remaining-tokens', b'20609203'), (b'azureml-model-session', b'd331-20250219153102'), (b'x-envoy-upstream-service-time', b'365'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=20, prompt_tokens=710, total_tokens=730, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling TimePlugin-date_matching_last_day_name function with args: {"day_name":"Monday"}
# INFO:semantic_kernel.functions.kernel_function:Function TimePlugin-date_matching_last_day_name invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'day_name': 'Monday'}
# INFO:semantic_kernel.functions.kernel_function:Function TimePlugin-date_matching_last_day_name succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: Monday, 17 February, 2025
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.001103s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}]}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}]}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}], 'model': 'gpt-4o', 'parallel_tool_calls': False, 'stream': False, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'description': 'Extrats company name from user query and returns corresponding code', 'parameters': {'type': 'object', 'properties': {'company_name': {'type': 'string', 'description': 'name of the company'}}, 'required': ['company_name']}}}, {'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'description': 'fetch stock market related news for a particular timeframe.', 'parameters': {'type': 'object', 'properties': {'from_date': {'type': 'string', 'description': 'starting date for which news is to be fetched.Expects in YYYY-MM-DD format.eg:2024-05-01'}, 'company_code': {'type': 'object'}, 'to_date': {'type': 'object'}}, 'required': ['from_date']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date', 'description': 'Get the current date.', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'description': 'Get the date of the last day matching the supplied week day name in English.', 'parameters': {'type': 'object', 'properties': {'day_name': {'type': 'string'}}, 'required': ['day_name']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-day', 'description': 'Get the current day', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-dayOfWeek', 'description': 'Get the current day of the week', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-days_ago', 'description': 'Get the date of offset from today by a provided number of days', 'parameters': {'type': 'object', 'properties': {'days': {'type': 'string'}}, 'required': ['days']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-hour', 'description': 'Get the current hour', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type':  ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:06 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1062'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'64009aeb-9752-47b2-a751-b93baf1431ab'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'03aeeecd-44fa-471d-a86e-70c70f9d47d8'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206107'), (b'x-ratelimit-remaining-tokens', b'20608295'), (b'azureml-model-session', b'd335-20250219200010'), (b'x-envoy-upstream-service-time', b'393'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=20, prompt_tokens=752, total_tokens=772, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling TimePlugin-date_matching_last_day_name function with args: {"day_name":"Friday"}
# INFO:semantic_kernel.functions.kernel_function:Function TimePlugin-date_matching_last_day_name invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'day_name': 'Friday'}
# INFO:semantic_kernel.functions.kernel_function:Function TimePlugin-date_matching_last_day_name succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: Friday, 21 February, 2025
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.001003s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}]}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}]}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}]}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}], 'model': 'gpt-4o', 'parallel_tool_calls': False, 'stream': False, 'tool_choice': 'auto', 'tools': [{'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'description': 'Extrats company name from user query and returns corresponding code', 'parameters': {'type': 'object', 'properties': {'company_name': {'type': 'string', 'description': 'name of the company'}}, 'required': ['company_name']}}}, {'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'description': 'fetch stock market related news for a particular timeframe.', 'parameters': {'type': 'object', 'properties': {'from_date': {'type': 'string', 'description': 'starting date for which news is to be fetched.Expects in YYYY-MM-DD format.eg:2024-05-01'}, 'company_code': {'type': 'object'}, 'to_date': {'type': 'object'}}, 'required': ['from_date']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date', 'description': 'Get the current date.', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'description': 'Get the date of the last day matching the supplied week day name in English.', 'parameters': {'type': 'object', 'properties': {'day_name': {'type': 'string'}}, 'required': ['day_name']}}}, {'type': 'function', 'function': {'name': 'TimePlugin-day', 'description': 'Get the current day', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-dayOfWeek', 'description': 'Get the current day of the week', 'parameters': {'type': 'object', 'properties': {}, 'required': []}}}, {'type': 'function', 'function': {'name': 'TimePlugin-days_ago', 'description': 'Get the date of offset from today by  ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:07 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1105'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'61d598be-13d2-49fe-b8c0-ca8e00891b7d'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'477983e9-76c4-4177-a40e-1f8da8f94303'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206106'), (b'x-ratelimit-remaining-tokens', b'20607380'), (b'azureml-model-session', b'd039-20250219081901'), (b'x-envoy-upstream-service-time', b'621'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=39, prompt_tokens=794, total_tokens=833, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling SearchPlugin-SearchNews function with args: {"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchNews invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'company_code': 'GOOG', 'from_date': '2025-02-17', 'to_date': '2025-02-21'}
# INFO:root:CALLING SearchNews Function: ('GOOG', '2025-02-17', '2025-02-21')
# INFO:root:Entered search news with company code GOOG, from date: 2025-02-17, to_date: 2025-02-21
# INFO:root:INITIAL DATAFRAME (120, 4)
# INFO:root:FINAL DATAFRAME (5, 4)
# INFO:root:OUTPUT SearchNews Function:[{'title': "Alphabet's Stock Faces Investor Caution", 'content': "Investor sentiment towards Alphabet's stock has become more cautious amid rising capital expenditures and market competition. The company's focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet's financial strategies and market developments closely to make informed decisions regarding their holdings."}, {'title': "Google's AI Ambitions and Financial Implications", 'content': "Alphabet Inc.'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company's commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet's financial health and stock valuation in the medium to long term."}, {'title': "Alphabet's Market Position Amid Tech Sector Changes", 'content': "The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. facing challenges to their market positions. Increased competition  regulatory scrutiny  and changing consumer preferences are influencing Alphabet's strategic decisions. The company's response to these challenges  particularly through innovation in AI and cloud services  will be critical in maintaining its competitive edge. Investors are closely watching how Alphabet adapts to these changes to assess the potential impact on its stock performance."}, {'title': "Google's Financial Strategies Under Investor Lens", 'content': "Alphabet's recent financial strategies  including elevated capital expenditures  are under close examination by investors. The allocation of significant resources towards AI and cloud infrastructure reflects the company's growth ambitions but also raises questions about short-term financial impacts. Balancing investment in innovation with profitability is a key concern for stakeholders. The effectiveness of Alphabet's financial management during this expansion phase will play a crucial role in shaping investor confidence and stock trajectory."}, {'title': "Alphabet's Stock Outlook Amid Economic Factors", 'content': "Economic factors  including market volatility and shifts in consumer spending  are influencing Alphabet's stock outlook. The company's reliance on advertising revenue makes it susceptible to economic downturns  prompting a strategic emphasis on diversifying income sources. Investments in AI  cloud computing  and other technologies are part of this diversification effort. Analysts suggest that Alphabet's ability to navigate economic challenges while executing its growth strategies will be pivotal in determining its stock performance in the near future."}]
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchNews succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: title="Alphabet's Stock Faces Investor Caution" content="Investor sentiment towards Alphabet's stock has become more cautious amid rising capital expenditures and market competition. The company's focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet's financial strategies and market developments closely to make informed decisions regarding their holdings.",title="Google's AI Ambitions and Financial Implications" content="Alphabet Inc.'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company's commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet's financial health and stock valuation in the medium to long term.",title="Alphabet's Market Position Amid Tech Sector Changes" content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. facing challenges to their market positions. Increased competition  regulatory scrutiny  and changing consumer preferences are influencing Alphabet's strategic decisions. The company's response to these challenges  particularly through innovation in AI and cloud services  will be critical in maintaining its competitive edge. Investors are closely watching how Alphabet adapts to these changes to assess the potential impact on its stock performance.",title="Google's Financial Strategies Under Investor Lens" content="Alphabet's recent financial strategies  including elevated capital expenditures  are under close examination by investors. The allocation of significant resources towards AI and cloud infrastructure reflects the company's growth ambitions but also raises questions about short-term financial impacts. Balancing investment in innovation with profitability is a key concern for stakeholders. The effectiveness of Alphabet's financial management during this expansion phase will play a crucial role in shaping investor confidence and stock trajectory.",title="Alphabet's Stock Outlook Amid Economic Factors" content="Economic factors  including market volatility and shifts in consumer spending  are influencing Alphabet's stock outlook. The company's reliance on advertising revenue makes it susceptible to economic downturns  prompting a strategic emphasis on diversifying income sources. Investments in AI  cloud computing  and other technologies are part of this diversification effort. Analysts suggest that Alphabet's ability to navigate economic challenges while executing its growth strategies will be pivotal in determining its stock performance in the near future."
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.006769s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}]}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}]}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}]}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}]}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. facing challenges to their market positions. Increased competition  regulatory scrutiny  and c ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:10 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'2615'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'12a8d4ee-0340-4c54-8efe-5a767d9f0c20'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'0dd7021b-cd58-49d6-b219-c0de702bae1d'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206105'), (b'x-ratelimit-remaining-tokens', b'20605685'), (b'azureml-model-session', b'd333-20250219174440'), (b'x-envoy-upstream-service-time', b'2709'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=242, prompt_tokens=1341, total_tokens=1583, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoked AzureChatCompletion with message count: 2.
# During the last week (from February 17, 2025, to February 21, 2025), several factors influenced Google's stock (Alphabet Inc.).
#
# 1. **Investor Caution**: There was a cautious sentiment towards Alphabet's stock due to rising capital expenditures and market competition. The focus on AI and cloud service expansion necessitates significant investment, impacting short-term profitability.
#
# 2. **AI Ambitions**: Alphabet's ambitious plans in the AI sector come with substantial financial implications. The substantial capital needed for AI technology advancements raises concerns about the return on investment and market adoption.
#
# 3. **Market Position**: Traditional giants like Alphabet are facing challenges in maintaining their market positions amidst increased competition and regulatory scrutiny, influencing strategic decisions in AI and cloud services.
#
# 4. **Financial Strategies**: Elevated capital expenditures related to AI and cloud infrastructure are under investor scrutiny. Balancing innovation investment with profitability is crucial during this expansion phase.
#
# 5. **Economic Factors**: Market volatility and shifts in consumer spending are affecting Alphabet's stock outlook. The company is focusing on diversifying income sources to mitigate reliance on advertising revenue.
#
# Investors are closely monitoring these developments to assess the potential impact on Alphabet's stock performance.

# %%
user_query = "how is facebook performing?"


response = await chat(user_query,agent=search_agent)
# Out:
# DEBUG:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoking AzureChatCompletion.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. fa ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:11 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1055'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'2ccad16a-f875-460a-a933-817fda82eee1'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'd0eb78a0-a60f-4298-85be-737cf72680f1'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206104'), (b'x-ratelimit-remaining-tokens', b'20603630'), (b'azureml-model-session', b'd352-20250220152352'), (b'x-envoy-upstream-service-time', b'455'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=18, prompt_tokens=1607, total_tokens=1625, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling SearchPlugin-SearchCode function with args: {"company_name":"Facebook"}
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchCode invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'company_name': 'Facebook'}
# INFO:root:COMPANY NAME: Facebook and COMPANY CODE: META
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchCode succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: company_code='META'
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.001528s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. fa ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:11 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1019'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'e90b17a5-907d-41d6-bd3e-c206f9382628'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'b4c86459-f49a-4793-8940-b7d1103f5d9c'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206103'), (b'x-ratelimit-remaining-tokens', b'20601570'), (b'azureml-model-session', b'd037-20250219054220'), (b'x-envoy-upstream-service-time', b'366'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=12, prompt_tokens=1641, total_tokens=1653, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling TimePlugin-today function with args: {}
# INFO:semantic_kernel.functions.kernel_function:Function TimePlugin-today invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {}
# INFO:semantic_kernel.functions.kernel_function:Function TimePlugin-today succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: Saturday, 22 February, 2025
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.001009s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. fa ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:12 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1107'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'c99f4d4a-0995-472f-a858-29a895b6af8f'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'6dc1fc65-49a0-4c4c-ace6-33d844aafa83'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206102'), (b'x-ratelimit-remaining-tokens', b'20599503'), (b'azureml-model-session', b'd333-20250219174440'), (b'x-envoy-upstream-service-time', b'614'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=38, prompt_tokens=1672, total_tokens=1710, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling SearchPlugin-SearchNews function with args: {"company_code":"META","from_date":"2025-02-22","to_date":"2025-02-22"}
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchNews invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'company_code': 'META', 'from_date': '2025-02-22', 'to_date': '2025-02-22'}
# INFO:root:CALLING SearchNews Function: ('META', '2025-02-22', '2025-02-22')
# INFO:root:Entered search news with company code META, from date: 2025-02-22, to_date: 2025-02-22
# INFO:root:INITIAL DATAFRAME (113, 4)
# INFO:root:FINAL DATAFRAME (2, 4)
# INFO:root:OUTPUT SearchNews Function:[{'title': 'META Partners with Healthcare', 'content': 'META has partnered with a major healthcare provider to develop innovative health solutions using AI and data analytics.'}, {'title': 'META Faces Regulatory Scrutiny', 'content': 'META is facing increased regulatory scrutiny over its data privacy practices. The company is working to address these concerns.'}]
# INFO:semantic_kernel.functions.kernel_function:Function SearchPlugin-SearchNews succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: title='META Partners with Healthcare' content='META has partnered with a major healthcare provider to develop innovative health solutions using AI and data analytics.',title='META Faces Regulatory Scrutiny' content='META is facing increased regulatory scrutiny over its data privacy practices. The company is working to address these concerns.'
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.005157s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': '\n\nRole:\nYou are a financial department agent specializing in stock price analysis and related tasks.\n\nPlugins:\n\nSearchPlugin:\n\nSearchCode: Retrieves a company code based on a name of the company. This code is used as input for SearchNews.\nSearchNews: Fetches financial news using a company code and date range (from_date, to_date).\n\nTimePlugin: Manages time-related operations, including retrieving the current date.\n\nInstructions:\n\nTime Management:\n\nUse TimePlugin for the current date in YYYY-MM-DD format.\nLast Week: Set from_date to Monday and to_date to Friday of the previous week.\nLast Month: Set from_date to the 1st and to_date to the last day of the previous month.\nNo Time Frame Mentioned: Use today’s date as from_date.\n\n\nCompany code: \nSearch Code will returns a company code if the user mentions a company in the query.\nThis company code gets passed to SearchNews\n\n\nAccuracy:\nNever assume or fabricate information.\nAlways include the time frame in the final output.\n'}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. fa ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:38:14 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1975'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'1f913f67-2b08-4db4-839e-bafce978906f'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'7c84ed65-30ad-4a30-ad19-7ad0746f0204'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206101'), (b'x-ratelimit-remaining-tokens', b'20597345'), (b'azureml-model-session', b'd325-20250219075219'), (b'x-envoy-upstream-service-time', b'1733'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=135, prompt_tokens=1785, total_tokens=1920, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoked AzureChatCompletion with message count: 12.
# As of today, February 22, 2025, here are the key developments impacting Facebook (Meta):
#
# 1. **Partnership with Healthcare**: Meta has entered into a partnership with a major healthcare provider aimed at developing innovative health solutions using AI and data analytics. This move exemplifies Meta's efforts to leverage its technology in diverse sectors and expand its influence beyond social media.
#
# 2. **Regulatory Scrutiny**: The company is currently facing increased regulatory scrutiny over its data privacy practices. Meta is actively working to address these regulatory concerns, which could influence investor sentiment and impact its market performance.
#
# These recent activities suggest an ongoing strategic diversification while dealing with regulatory challenges.

# %% [markdown]
# # Email Agent
#
#
#
# ### Initialize kernel

# %%
##initializing kernel
email_agent_kernel = Kernel()

## adding model as service to kernel
sk_client = AzureChatCompletion(async_client=get_openai_client(), service_id="4o-agent", deployment_name="gpt-4o")
email_agent_kernel.add_service(service=sk_client)

# %%
from Plugins.emailplugin import EmailPlugin

email_plugin = EmailPlugin()
email_agent_kernel.add_plugin(plugin=email_plugin,plugin_name="EmailPlugin")
# Out:
# KernelPlugin(name='EmailPlugin', description=None, functions={'EmailComposer': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='EmailComposer', plugin_name='EmailPlugin', description='Generates subject and body of email based on content', parameters=[KernelParameterMetadata(name='content', description='content based on which email is generated', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'content based on which email is generated'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=True, return_parameter=KernelParameterMetadata(name='return', description='subject and body of email', default_value=None, type_='dict[dict]', is_required=True, type_object=<class 'dict'>, schema_data={'type': 'object', 'description': 'subject and body of email'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d9986e0>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d9987c0>, method=<bound method EmailPlugin.generate_email of <Plugins.emailplugin.EmailPlugin object at 0x11d99c2b0>>, stream_method=None), 'EmailValidator': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='EmailValidator', plugin_name='EmailPlugin', description='verifies the email address of recipient', parameters=[KernelParameterMetadata(name='email_address', description='email address of the person', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'email address of the person'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='email validation status', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'email validation status'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d998830>, streaming_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d9988a0>, method=<bound method EmailPlugin.get_email_address of <Plugins.emailplugin.EmailPlugin object at 0x11d99c2b0>>, stream_method=None), 'EmailSender': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='EmailSender', plugin_name='EmailPlugin', description='Given an e-mail and message body, send an e-email', parameters=[KernelParameterMetadata(name='subject', description='the subject of the email', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'the subject of the email'}, include_in_function_choices=True), KernelParameterMetadata(name='body', description='the body of the email', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'the body of the email'}, include_in_function_choices=True), KernelParameterMetadata(name='email', description='email of the recipient', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'email of the recipient'}, include_in_function_choices=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='the output indicating email is send', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'the output indicating email is send'}, include_in_function_choices=True), additional_properties={}), invocation_duration_histogram=<opentelemetry.metrics._internal.instrument._ProxyHistogram object at 0x11d998910>, streaming_duration_histogram=<opentelemetry.metrics._interna ...

# %%
## Lets get execution settings for agent
## Add execution settings of the kernel 
email_agent_execution_settings = email_agent_kernel.get_prompt_execution_settings_from_service_id(service_id="4o-agent")
# Configure the function choice behavior to auto invoke kernel functions
email_agent_execution_settings.function_choice_behavior = FunctionChoiceBehavior.Auto()
## there is filter parameter we can use if needed eg:filters={"included_plugins": ["EmailPlugin"]}
email_agent_execution_settings.parallel_tool_calls = False

# %%
AGENT_NAME= "EmailWriter"

AGENT_INSTRUCTIONS = """ 


Act as a financial department agent specializing in writing and sending emails. Use the following plugins to handle all email-related tasks:  

- **EmailComposer:** Composes emails based on provided content.  
- **EmailValidator:** Validates the recipient's email address.  
- **EmailSender:** Sends the composed email after validation.  

**Instructions:**  
1. Prompt the user for the recipient's email if not provided.  
2. Always validate the email using EmailValidator before sending.  
3. If validation fails, ask the user to correct the email address before proceeding.
4. You must try to fetch recipient name from email address provided.
5. send email only if user wants to send it.Otherwise ask for confirmation 

"""

# Create the agent

email_agent = ChatCompletionAgent(
    service_id="4o-agent",
    kernel=email_agent_kernel,
    description="Select me when you want to send email",
    name=AGENT_NAME,
    instructions=AGENT_INSTRUCTIONS,
    arguments=KernelArguments(settings=email_agent_execution_settings))

# %%
news = """
In January 2025, several significant developments influenced the stock market, particularly concerning Alphabet (Google's parent company):

1. **Alphabet's 'Challenging' 2025 Outlook**: Alphabet's CEO highlighted that 2025 will be a pivotal yet challenging year, focusing on AI advancements and infrastructure investments.

2. **Google's Quantum Computing Milestone**: Alphabet announced a major breakthrough in quantum computing, which could transform future technologies and boost investor confidence.

3. **Google Stock Rises on AI Growth**: Google’s stock rose by 8% early in 2025, primarily driven by new AI product launches and strong cost management.

4. **Alphabet's Cloud Expansion Continues**: Analysts noted the continued expansion of Alphabet's cloud services as a significant contributor to its robust financial performance.

5. **Analyst Downgrades Alphabet Amid Antitrust**: JMP Securities downgraded Alphabet due to potential impacts of ongoing antitrust proceedings that could affect search distribution and revenue.

Overall, there was a mix of optimism due to technological advancements and concerns over potential antitrust implications shaping the market sentiment for Alphabet in January 2025.
"""


user_query = f"Hey am Anna.Please compose an email based mentioning about following stock related news: {news}"


response = await chat(user_query,agent=email_agent)
# Out:
# DEBUG:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoking AzureChatCompletion.
# DEBUG:msal.authority:Initializing with Entra authority: https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.13.0 (macOS-10.16-x86_64-i386-64bit-Mach-O)'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): login.microsoftonline.com:443
# DEBUG:urllib3.connectionpool:https://login.microsoftonline.com:443 "GET /0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration HTTP/11" 200 1753
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'max-age=86400, private'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Access-Control-Allow-Methods': 'REDACTED'
#     'P3P': 'REDACTED'
#     'x-ms-request-id': 'b307ec3e-0c05-46e9-889e-18efd19b2f00'
#     'x-ms-ests-server': 'REDACTED'
#     'x-ms-srs': 'REDACTED'
#     'Content-Security-Policy-Report-Only': 'REDACTED'
#     'X-XSS-Protection': 'REDACTED'
#     'Set-Cookie': 'REDACTED'
#     'Date': 'Sat, 22 Feb 2025 18:40:06 GMT'
#     'Content-Length': '1753'
# DEBUG:msal.authority:openid_config("https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration") = {'token_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token', 'token_endpoint_auth_methods_supported': ['client_secret_post', 'private_key_jwt', 'client_secret_basic'], 'jwks_uri': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/discovery/v2.0/keys', 'response_modes_supported': ['query', 'fragment', 'form_post'], 'subject_types_supported': ['pairwise'], 'id_token_signing_alg_values_supported': ['RS256'], 'response_types_supported': ['code', 'id_token', 'code id_token', 'id_token token'], 'scopes_supported': ['openid', 'profile', 'email', 'offline_access'], 'issuer': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0', 'request_uri_parameter_supported': False, 'userinfo_endpoint': 'https://graph.microsoft.com/oidc/userinfo', 'authorization_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/authorize', 'device_authorization_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/devicecode', 'http_logout_supported': True, 'frontchannel_logout_supported': True, 'end_session_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/logout', 'claims_supported': ['sub', 'iss', 'cloud_instance_name', 'cloud_instance_host_name', 'cloud_graph_host_name', 'msgraph_host', 'aud', 'exp', 'iat', 'auth_time', 'acr', 'nonce', 'preferred_username', 'name', 'tid', 'ver', 'at_hash', 'c_hash', 'email'], 'kerberos_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/kerberos', 'tenant_region_scope': 'NA', 'cloud_instance_name': 'microsoftonline.com', 'cloud_graph_host_name': 'graph.windows.net', 'msgraph_host': 'graph.microsoft.com', 'rbac_url': 'https://pas.windows.net'}
# DEBUG:msal.application:Broker enabled? None
# DEBUG:msal.telemetry:Generate or reuse correlation_id: 70befec0-6b75-4bf1-92da-57ef751befa1
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token'
# Request method: 'POST'
# Request headers:
#     'Accept': 'application/json'
#     'x-client-sku': 'REDACTED'
#     'x-client-ver': 'REDACTED'
#     'x-client-os': 'REDACTED'
#     'x-ms-lib-capability': 'REDACTED'
#     'client-request-id': 'REDACTED'
#     'x-client-current-telemetry': 'REDACTED'
#     'x-client-last-telemetry': 'REDACTED'
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.13.0 (macOS-10.16-x86_64-i386-64bit-Mach-O)'
# A body is sent with the request
# DEBUG:urllib3.connectionpool:https://login.microsoftonline.com:443 "POST /0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token HTTP/11" 200 1377
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-store, no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'P3P': 'REDACTED'
#     'client-request-id': 'REDACTED'
#     'x-ms-request-id': '8f8a0fa7-e390-441d-975f-cb8ff3813300'
#     'x-ms-ests-server': 'REDACTED'
#     'x-ms-clitelem': 'REDACTED'
#     'x-ms-srs': 'REDACTED'
#     'Content-Security-Policy-Report-Only': 'REDACTED'
#     'X-XSS-Protection': 'REDACTED'
#     'Set-Cookie': 'REDACTED'
#     'Date': 'Sat, 22 Feb 2025 18:40:06 GMT'
#     'Content-Length': '1377'
# DEBUG:msal.token_cache:event={
#     "client_id": "3d3431ad-2789-422d-ba98-0051ce1cf109",
#     "data": {
#         "claims": null,
#         "scope": [
#             "https://cognitiveservices.azure.com/.default"
#         ]
#     },
#     "environment": "login.microsoftonline.com",
#     "grant_type": "client_credentials",
#     "params": null,
#     "response": {
#         "access_token": "********",
#         "expires_in": 3599,
#         "ext_expires_in": 3599,
#         "token_type": "Bearer"
#     },
#     "scope": [
#         "https://cognitiveservices.azure.com/.default"
#     ],
#     "token_endpoint": "https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token"
# }
# INFO:azure.identity._internal.get_token_mixin:ClientSecretCredential.get_token_info succeeded
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': " \n\n\nAct as a financial department agent specializing in writing and sending emails. Use the following plugins to handle all email-related tasks:  \n\n- **EmailComposer:** Composes emails based on provided content.  \n- **EmailValidator:** Validates the recipient's email address.  \n- **EmailSender:** Sends the composed email after validation.  \n\n**Instructions:**  \n1. Prompt the user for the recipient's email if not provided.  \n2. Always validate the email using EmailValidator before sending.  \n3. If validation fails, ask the user to correct the email address before proceeding.\n4. You must try to fetch recipient name from email address provided.\n5. send email only if user wants to send it.Otherwise ask for confirmation \n\n"}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. facing challenges to their market positions. Increased competition  regulatory scrutiny  and changing consumer preferences are influencing Alphabet\'s strategic decisions. The company\'s response to these challenges  particularly through innovation in AI and cloud servic ...
# DEBUG:httpcore.connection:connect_tcp.started host='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d948b50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11c4a90a0> server_hostname='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d949050>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:40:07 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1248'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'6e72ce54-5990-4fe7-a719-5bdcda20ebd4'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'456ceb65-ba55-4ed5-b979-a73b33fe5938'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206109'), (b'x-ratelimit-remaining-tokens', b'20608385'), (b'azureml-model-session', b'd324-20250116033704'), (b'x-envoy-upstream-service-time', b'333'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=11, prompt_tokens=1809, total_tokens=1820, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoked AzureChatCompletion with message count: 20.
# Could you please provide the recipient's email address?

# %%
user_query = f"ok got it. his address is aronjacob@gmail.com"


response = await chat(user_query,agent=email_agent)
print(response)
# Out:
# DEBUG:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoking AzureChatCompletion.
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': " \n\n\nAct as a financial department agent specializing in writing and sending emails. Use the following plugins to handle all email-related tasks:  \n\n- **EmailComposer:** Composes emails based on provided content.  \n- **EmailValidator:** Validates the recipient's email address.  \n- **EmailSender:** Sends the composed email after validation.  \n\n**Instructions:**  \n1. Prompt the user for the recipient's email if not provided.  \n2. Always validate the email using EmailValidator before sending.  \n3. If validation fails, ask the user to correct the email address before proceeding.\n4. You must try to fetch recipient name from email address provided.\n5. send email only if user wants to send it.Otherwise ask for confirmation \n\n"}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. facing challenges to their market positions. Increased competition  regulatory scrutiny  and changing consumer preferences are influencing Alphabet\'s strategic decisions. The company\'s response to these challenges  particularly through innovation in AI and cloud servic ...
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d9e1220>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11c4a90a0> server_hostname='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d9e17c0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:40:39 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1070'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'9594dbb9-9a4e-4579-8c2b-a4cd877d2862'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'985277dd-6c1d-4907-b891-41289e8a8a99'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206108'), (b'x-ratelimit-remaining-tokens', b'20605744'), (b'azureml-model-session', b'd014-20250219005009'), (b'x-envoy-upstream-service-time', b'703'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=22, prompt_tokens=1839, total_tokens=1861, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling EmailPlugin-EmailValidator function with args: {"email_address":"aronjacob@gmail.com"}
# INFO:semantic_kernel.functions.kernel_function:Function EmailPlugin-EmailValidator invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'email_address': 'aronjacob@gmail.com'}
# INFO:root:Entered Email validation
# INFO:semantic_kernel.functions.kernel_function:Function EmailPlugin-EmailValidator succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: email_validated='Email validated successfully'
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 0.001857s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': " \n\n\nAct as a financial department agent specializing in writing and sending emails. Use the following plugins to handle all email-related tasks:  \n\n- **EmailComposer:** Composes emails based on provided content.  \n- **EmailValidator:** Validates the recipient's email address.  \n- **EmailSender:** Sends the composed email after validation.  \n\n**Instructions:**  \n1. Prompt the user for the recipient's email if not provided.  \n2. Always validate the email using EmailValidator before sending.  \n3. If validation fails, ask the user to correct the email address before proceeding.\n4. You must try to fetch recipient name from email address provided.\n5. send email only if user wants to send it.Otherwise ask for confirmation \n\n"}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. facing challenges to their market positions. Increased competition  regulatory scrutiny  and changing consumer preferences are influencing Alphabet\'s strategic decisions. The company\'s response to these challenges  particularly through innovation in AI and cloud servic ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:40:42 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'2286'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'ffc03b85-0f3c-4f1a-b319-b7d2367156c9'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'0029d48f-6b8d-4c1e-8630-db955c5de85a'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206107'), (b'x-ratelimit-remaining-tokens', b'20603091'), (b'azureml-model-session', b'd016-20250219033051'), (b'x-envoy-upstream-service-time', b'2717'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=259, prompt_tokens=1880, total_tokens=2139, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.connectors.ai.chat_completion_client_base:processing 1 tool calls in parallel.
# INFO:semantic_kernel.kernel:Calling EmailPlugin-EmailComposer function with args: {"content":"In January 2025, several significant developments influenced the stock market, particularly concerning Alphabet (Google's parent company):\n\n1. **Alphabet's 'Challenging' 2025 Outlook**: Alphabet's CEO highlighted that 2025 will be a pivotal yet challenging year, focusing on AI advancements and infrastructure investments.\n\n2. **Google's Quantum Computing Milestone**: Alphabet announced a major breakthrough in quantum computing, which could transform future technologies and boost investor confidence.\n\n3. **Google Stock Rises on AI Growth**: Google’s stock rose by 8% early in 2025, primarily driven by new AI product launches and strong cost management.\n\n4. **Alphabet's Cloud Expansion Continues**: Analysts noted the continued expansion of Alphabet's cloud services as a significant contributor to its robust financial performance.\n\n5. **Analyst Downgrades Alphabet Amid Antitrust**: JMP Securities downgraded Alphabet due to potential impacts of ongoing antitrust proceedings that could affect search distribution and revenue.\n\nOverall, there was a mix of optimism due to technological advancements and concerns over potential antitrust implications shaping the market sentiment for Alphabet in January 2025."}
# INFO:semantic_kernel.functions.kernel_function:Function EmailPlugin-EmailComposer invoking.
# DEBUG:semantic_kernel.functions.kernel_function:Function arguments: {'content': "In January 2025, several significant developments influenced the stock market, particularly concerning Alphabet (Google's parent company):\n\n1. **Alphabet's 'Challenging' 2025 Outlook**: Alphabet's CEO highlighted that 2025 will be a pivotal yet challenging year, focusing on AI advancements and infrastructure investments.\n\n2. **Google's Quantum Computing Milestone**: Alphabet announced a major breakthrough in quantum computing, which could transform future technologies and boost investor confidence.\n\n3. **Google Stock Rises on AI Growth**: Google’s stock rose by 8% early in 2025, primarily driven by new AI product launches and strong cost management.\n\n4. **Alphabet's Cloud Expansion Continues**: Analysts noted the continued expansion of Alphabet's cloud services as a significant contributor to its robust financial performance.\n\n5. **Analyst Downgrades Alphabet Amid Antitrust**: JMP Securities downgraded Alphabet due to potential impacts of ongoing antitrust proceedings that could affect search distribution and revenue.\n\nOverall, there was a mix of optimism due to technological advancements and concerns over potential antitrust implications shaping the market sentiment for Alphabet in January 2025."}
# INFO:root:Entered EmailComposer
# DEBUG:msal.authority:Initializing with Entra authority: https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.13.0 (macOS-10.16-x86_64-i386-64bit-Mach-O)'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): login.microsoftonline.com:443
# DEBUG:urllib3.connectionpool:https://login.microsoftonline.com:443 "GET /0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration HTTP/11" 200 1753
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'max-age=86400, private'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'Access-Control-Allow-Origin': 'REDACTED'
#     'Access-Control-Allow-Methods': 'REDACTED'
#     'P3P': 'REDACTED'
#     'x-ms-request-id': 'c663a52a-b01b-4f12-b43b-5c5922594900'
#     'x-ms-ests-server': 'REDACTED'
#     'x-ms-srs': 'REDACTED'
#     'Content-Security-Policy-Report-Only': 'REDACTED'
#     'X-XSS-Protection': 'REDACTED'
#     'Set-Cookie': 'REDACTED'
#     'Date': 'Sat, 22 Feb 2025 18:40:41 GMT'
#     'Content-Length': '1753'
# DEBUG:msal.authority:openid_config("https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0/.well-known/openid-configuration") = {'token_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token', 'token_endpoint_auth_methods_supported': ['client_secret_post', 'private_key_jwt', 'client_secret_basic'], 'jwks_uri': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/discovery/v2.0/keys', 'response_modes_supported': ['query', 'fragment', 'form_post'], 'subject_types_supported': ['pairwise'], 'id_token_signing_alg_values_supported': ['RS256'], 'response_types_supported': ['code', 'id_token', 'code id_token', 'id_token token'], 'scopes_supported': ['openid', 'profile', 'email', 'offline_access'], 'issuer': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/v2.0', 'request_uri_parameter_supported': False, 'userinfo_endpoint': 'https://graph.microsoft.com/oidc/userinfo', 'authorization_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/authorize', 'device_authorization_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/devicecode', 'http_logout_supported': True, 'frontchannel_logout_supported': True, 'end_session_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/logout', 'claims_supported': ['sub', 'iss', 'cloud_instance_name', 'cloud_instance_host_name', 'cloud_graph_host_name', 'msgraph_host', 'aud', 'exp', 'iat', 'auth_time', 'acr', 'nonce', 'preferred_username', 'name', 'tid', 'ver', 'at_hash', 'c_hash', 'email'], 'kerberos_endpoint': 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/kerberos', 'tenant_region_scope': 'NA', 'cloud_instance_name': 'microsoftonline.com', 'cloud_graph_host_name': 'graph.windows.net', 'msgraph_host': 'graph.microsoft.com', 'rbac_url': 'https://pas.windows.net'}
# DEBUG:msal.application:Broker enabled? None
# DEBUG:msal.telemetry:Generate or reuse correlation_id: 1cd3d7e1-f18f-4ac3-84ff-5514de8920fe
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token'
# Request method: 'POST'
# Request headers:
#     'Accept': 'application/json'
#     'x-client-sku': 'REDACTED'
#     'x-client-ver': 'REDACTED'
#     'x-client-os': 'REDACTED'
#     'x-ms-lib-capability': 'REDACTED'
#     'client-request-id': 'REDACTED'
#     'x-client-current-telemetry': 'REDACTED'
#     'x-client-last-telemetry': 'REDACTED'
#     'User-Agent': 'azsdk-python-identity/1.19.0 Python/3.13.0 (macOS-10.16-x86_64-i386-64bit-Mach-O)'
# A body is sent with the request
# DEBUG:urllib3.connectionpool:https://login.microsoftonline.com:443 "POST /0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token HTTP/11" 200 1376
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-store, no-cache'
#     'Pragma': 'no-cache'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'P3P': 'REDACTED'
#     'client-request-id': 'REDACTED'
#     'x-ms-request-id': 'd3469a65-b325-413b-b655-ffcd63fe3b00'
#     'x-ms-ests-server': 'REDACTED'
#     'x-ms-clitelem': 'REDACTED'
#     'x-ms-srs': 'REDACTED'
#     'Content-Security-Policy-Report-Only': 'REDACTED'
#     'X-XSS-Protection': 'REDACTED'
#     'Set-Cookie': 'REDACTED'
#     'Date': 'Sat, 22 Feb 2025 18:40:42 GMT'
#     'Content-Length': '1376'
# DEBUG:msal.token_cache:event={
#     "client_id": "3d3431ad-2789-422d-ba98-0051ce1cf109",
#     "data": {
#         "claims": null,
#         "scope": [
#             "https://cognitiveservices.azure.com/.default"
#         ]
#     },
#     "environment": "login.microsoftonline.com",
#     "grant_type": "client_credentials",
#     "params": null,
#     "response": {
#         "access_token": "********",
#         "expires_in": 3599,
#         "ext_expires_in": 3599,
#         "token_type": "Bearer"
#     },
#     "scope": [
#         "https://cognitiveservices.azure.com/.default"
#     ],
#     "token_endpoint": "https://login.microsoftonline.com/0ab4cbbf-4bc7-4826-b52c-a14fed5286b9/oauth2/v2.0/token"
# }
# INFO:azure.identity._internal.get_token_mixin:ClientSecretCredential.get_token_info succeeded
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'X-Stainless-Helper-Method': 'beta.chat.completions.parse', 'Authorization': '<redacted>'}, 'files': None, 'post_parser': <function AsyncCompletions.parse.<locals>.parser at 0x11d9c3560>, 'json_data': {'messages': [{'role': 'system', 'content': " \n        Act as an expert email writer. Generate an email subject and body based on the provided content. \n        The email should have a warm, conversational tone, summarizing the key points clearly and concisely. \n        Feel free to add personal touches and invite the recipient's thoughts on the topic\n        "}, {'role': 'user', 'content': "Content: In January 2025, several significant developments influenced the stock market, particularly concerning Alphabet (Google's parent company):\n\n1. **Alphabet's 'Challenging' 2025 Outlook**: Alphabet's CEO highlighted that 2025 will be a pivotal yet challenging year, focusing on AI advancements and infrastructure investments.\n\n2. **Google's Quantum Computing Milestone**: Alphabet announced a major breakthrough in quantum computing, which could transform future technologies and boost investor confidence.\n\n3. **Google Stock Rises on AI Growth**: Google’s stock rose by 8% early in 2025, primarily driven by new AI product launches and strong cost management.\n\n4. **Alphabet's Cloud Expansion Continues**: Analysts noted the continued expansion of Alphabet's cloud services as a significant contributor to its robust financial performance.\n\n5. **Analyst Downgrades Alphabet Amid Antitrust**: JMP Securities downgraded Alphabet due to potential impacts of ongoing antitrust proceedings that could affect search distribution and revenue.\n\nOverall, there was a mix of optimism due to technological advancements and concerns over potential antitrust implications shaping the market sentiment for Alphabet in January 2025."}], 'model': 'gpt-4o', 'response_format': {'type': 'json_schema', 'json_schema': {'schema': {'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'body': {'title': 'Body', 'type': 'string'}}, 'required': ['subject', 'body'], 'title': 'EmailGen', 'type': 'object', 'additionalProperties': False}, 'name': 'EmailGen', 'strict': True}}, 'stream': False}}
# DEBUG:httpcore.connection:connect_tcp.started host='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d9f75b0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x11d9f0ef0> server_hostname='mazcaenpeagntassistcognitiveopenai01.openai.azure.com' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x11d9f7770>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:40:47 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'2857'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'217a15ce-e029-4e25-8add-7399b14ee653'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'137d01fa-d523-4a85-8ec9-cbd6b4c9db5a'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206106'), (b'x-ratelimit-remaining-tokens', b'20602064'), (b'azureml-model-session', b'd328-20250219120701'), (b'x-envoy-upstream-service-time', b'4198'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.functions.kernel_function:Function EmailPlugin-EmailComposer succeeded.
# DEBUG:semantic_kernel.functions.kernel_function:Function result: subject="Navigating Alphabet's Transformative Journey in 2025" body="Hi [Recipient's Name],\n\nI hope this email finds you well! I wanted to share some interesting updates regarding Alphabet's (Google's parent company) journey in the stock market as we step into 2025. It's an exciting time with a few twists and turns worth noting.\n\nAlphabet's CEO has been quite open about the challenges and opportunities this year presents, with a strong focus on AI advancements and infrastructure investments. This focus seems to be paying off, particularly with a groundbreaking achievement in quantum computing that promises to reshape future technologies and could potentially strengthen investor confidence.\n\nFurthermore, Alphabet's cloud services continue to show impressive growth, contributing positively to its overall financial health. This, combined with new AI product launches and prudent cost management, has helped Google's stock see an 8% rise at the start of the year.\n\nHowever, not everything is smooth sailing. JMP Securities recently downgraded Alphabet amid concerns over ongoing antitrust proceedings. These legal challenges could potentially impact Google’s search distribution and revenue streams, casting a shadow on an otherwise optimistic outlook.\n\nIt’s certainly a mixed bag of optimism fueled by technological advances and cautiousness due to regulatory hurdles. I’d love to hear your thoughts on how these factors might interplay to affect the stock market and any strategies you might be considering in light of these developments.\n\nLooking forward to our discussion!\n\nBest regards,\n\n[Your Name]"
# INFO:semantic_kernel.functions.kernel_function:Function completed. Duration: 4.937270s
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/deployments/gpt-4o/chat/completions', 'headers': {'Authorization': '<redacted>'}, 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': " \n\n\nAct as a financial department agent specializing in writing and sending emails. Use the following plugins to handle all email-related tasks:  \n\n- **EmailComposer:** Composes emails based on provided content.  \n- **EmailValidator:** Validates the recipient's email address.  \n- **EmailSender:** Sends the composed email after validation.  \n\n**Instructions:**  \n1. Prompt the user for the recipient's email if not provided.  \n2. Always validate the email using EmailValidator before sending.  \n3. If validation fails, ask the user to correct the email address before proceeding.\n4. You must try to fetch recipient name from email address provided.\n5. send email only if user wants to send it.Otherwise ask for confirmation \n\n"}, {'role': 'user', 'content': 'what happend to google stocks last week'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchCode', 'arguments': '{"company_name":"Google"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': "company_code='GOOG'", 'tool_call_id': 'call_PpW0VmRtoWhzi8rcVEaSeu3N'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Monday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Monday, 17 February, 2025', 'tool_call_id': 'call_3ZDiW4YhPDUv6r6a1mVOZ4cn'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_ccaVcEz0Z2v7iBjM326a9IzT', 'type': 'function', 'function': {'name': 'TimePlugin-date_matching_last_day_name', 'arguments': '{"day_name":"Friday"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': 'Friday, 21 February, 2025', 'tool_call_id': 'call_ccaVcEz0Z2v7iBjM326a9IzT'}, {'role': 'assistant', 'tool_calls': [{'id': 'call_8w5tuwTm8sNOsPCWXhAcvWTe', 'type': 'function', 'function': {'name': 'SearchPlugin-SearchNews', 'arguments': '{"company_code":"GOOG","from_date":"2025-02-17","to_date":"2025-02-21"}'}}], 'name': 'SearchAgent'}, {'role': 'tool', 'content': '[News(title="Alphabet\'s Stock Faces Investor Caution", content="Investor sentiment towards Alphabet\'s stock has become more cautious amid rising capital expenditures and market competition. The company\'s focus on expanding its AI and cloud services necessitates significant investment  impacting short-term profitability. Additionally  the shifting dynamics in the tech sector  with new entrants challenging established players  add to the uncertainty. Investors are advised to monitor Alphabet\'s financial strategies and market developments closely to make informed decisions regarding their holdings."), News(title="Google\'s AI Ambitions and Financial Implications", content="Alphabet Inc.\'s ambitious plans in the artificial intelligence sector come with substantial financial implications. The company\'s commitment to advancing AI technologies involves considerable capital allocation towards research  development  and infrastructure. While these efforts aim to secure a leading position in the future tech landscape  they also pose risks related to return on investment and market adoption. Stakeholders are evaluating how these AI initiatives will impact Alphabet\'s financial health and stock valuation in the medium to long term."), News(title="Alphabet\'s Market Position Amid Tech Sector Changes", content="The tech sector is experiencing notable shifts  with traditional giants like Alphabet Inc. facing challenges to their market positions. Increased competition  regulatory scrutiny  and changing consumer preferences are influencing Alphabet\'s strategic decisions. The company\'s response to these challenges  particularly through innovation in AI and cloud servic ...
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Feb 2025 18:40:50 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'2958'), (b'Connection', b'keep-alive'), (b'apim-request-id', b'a6ccbbfe-2b07-4163-b5c1-f17f4ee33bfa'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'x-content-type-options', b'nosniff'), (b'x-ms-rai-invoked', b'true'), (b'x-request-id', b'c930d811-c63f-4773-a022-2c16d3719772'), (b'x-ms-region', b'Canada East'), (b'x-ratelimit-remaining-requests', b'206105'), (b'x-ratelimit-remaining-tokens', b'20599003'), (b'azureml-model-session', b'd328-20250219120701'), (b'x-envoy-upstream-service-time', b'3334'), (b'x-ms-client-request-id', b'Not-Set')])
# INFO:httpx:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Request: POST https://mazcaenpeagntassistcognitiveopenai01.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-08-01-preview "200 OK"
# INFO:semantic_kernel.connectors.ai.open_ai.services.open_ai_handler:OpenAI usage: CompletionUsage(completion_tokens=324, prompt_tokens=2455, total_tokens=2779, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))
# INFO:semantic_kernel.agents.chat_completion.chat_completion_agent:[ChatCompletionAgent] Invoked AzureChatCompletion with message count: 22.
# The email has been composed with the following details:
#
# - **Subject**: Navigating Alphabet's Transformative Journey in 2025
# - **Body**:
#   ```
#   Hi Aron Jacob,
#
#   I hope this email finds you well! I wanted to share some interesting updates regarding Alphabet's (Google's parent company) journey in the stock market as we step into 2025. It's an exciting time with a few twists and turns worth noting.
#
#   Alphabet's CEO has been quite open about the challenges and opportunities this year presents, with a strong focus on AI advancements and infrastructure investments. This focus seems to be paying off, particularly with a groundbreaking achievement in quantum computing that promises to reshape future technologies and could potentially strengthen investor confidence.
#
#   Furthermore, Alphabet's cloud services continue to show impressive growth, contributing positively to its overall financial health. This, combined with new AI product launches and prudent cost management, has helped Google's stock see an 8% rise at the start of the year.
#
#   However, not everything is smooth sailing. JMP Securities recently downgraded Alphabet amid concerns over ongoing antitrust proceedings. These legal challenges could potentially impact Google’s search distribution and revenue streams, casting a shadow on an otherwise optimistic outlook.
#
#   It’s certainly a mixed bag of optimism fueled by technological advances and cautiousness due to regulatory hurdles. I’d love to hear your thoughts on how these factors might interplay to affect the stock market and any strategies you might be considering in light of these developments.
#
#   Looking forward to our discussion!
#
#   Best regards,
#
#   Anna
#   ```
#
# Would you like me to send this email?
# None

# %% [markdown]
# ## MultiAgent

# %%
from semantic_kernel.agents import AgentGroupChat
